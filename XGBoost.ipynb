# %% [markdown]
# # XGBoost   Extreme Gradient Boost

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Boston.csv')

# %%
df.shape
# Out:
# (506, 14)

# %%
X = df.iloc[:, 0:13]
y = df.iloc[:, -1]

# %%
print('X shape is' , X.shape)
print('y shape is' , y.shape)
# Out:
# X shape is (506, 13)
# y shape is (506,)

# %%
from xgboost import XGBRFRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
xgb = XGBRFRegressor(eta = 0.9, gamma = 20)
gb = GradientBoostingRegressor()
rf = RandomForestRegressor()

# %%
from sklearn.model_selection import cross_val_score

# %%
print('XGB', np.mean(cross_val_score(xgb, X, y, cv= 10)))
print('gb', np.mean(cross_val_score(gb, X, y, cv= 10)))
print('RF', np.mean(cross_val_score(rf, X, y, cv= 10)))
# Out:
# XGB 0.48962332522301477
# gb 0.43155279650921397
# RF 0.4964655363978479

# %% [markdown]
# ## Applying XGBoost on Titanic Dataset

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('Titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'], inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
X = df.iloc[:,1:]
y = df.iloc[:,0]

# %%
X
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         3    male  22.0      1      0   7.2500        S
# 1         1  female  38.0      1      0  71.2833        C
# 2         3  female  26.0      0      0   7.9250        S
# 3         1  female  35.0      1      0  53.1000        S
# 4         3    male  35.0      0      0   8.0500        S
# ..      ...     ...   ...    ...    ...      ...      ...
# 886       2    male  27.0      0      0  13.0000        S
# 887       1  female  19.0      0      0  30.0000        S
# 888       3  female   NaN      1      2  23.4500        S
# 889       1    male  26.0      0      0  30.0000        C
# 890       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=23)

# %%
X_train
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 151       1  female  22.0      1      0   66.6000        S
# 753       3    male  23.0      0      0    7.8958        S
# 746       3    male  16.0      1      1   20.2500        S
# 684       2    male  60.0      1      1   39.0000        S
# 887       1  female  19.0      0      0   30.0000        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 31        1  female   NaN      1      0  146.5208        C
# 488       3    male  30.0      0      0    8.0500        S
# 40        3  female  40.0      1      0    9.4750        S
# 742       1  female  21.0      2      2  262.3750        C
# 595       3    male  36.0      1      1   24.1500        S
#
# [712 rows x 7 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
trf1 = ColumnTransformer([
    
    ('impute', SimpleImputer(),[2]),
    ('impute2', SimpleImputer(strategy='most_frequent'),[6])
    
], remainder='passthrough')

# %%
trf1.fit_transform(X_train)
# Out:
# array([[22.0, 'S', 1, ..., 1, 0, 66.6],
#        [23.0, 'S', 3, ..., 0, 0, 7.8958],
#        [16.0, 'S', 3, ..., 1, 1, 20.25],
#        ...,
#        [40.0, 'S', 3, ..., 1, 0, 9.475],
#        [21.0, 'C', 1, ..., 2, 2, 262.375],
#        [36.0, 'S', 3, ..., 1, 1, 24.15]], dtype=object)

# %%
trf2 = ColumnTransformer([
    
    ('ohe', OneHotEncoder(sparse=False, handle_unknown='ignore'),[1,6])
    ])

# %%
from xgboost import XGBClassifier

# %%
clf = XGBClassifier()

# %%
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([
    ('step1',trf1),
    ('step2', trf2),
    ('step3', clf)
])

# %%
pipe.fit(X_train, y_train)
# Out:
# C:\Users\ASAD-AYUB\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute', SimpleImputer(),
#                                                   [2]),
#                                                  ('impute2',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [6])])),
#                 ('step2',
#                  ColumnTransformer(transformers=[('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
# ...

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.659217877094972

# %%
pipe.predict(np.array([[1, 'female', 33.0,1,0, 27.72,'C']], dtype=object))
# Out:
# C:\Users\ASAD-AYUB\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\ASAD-AYUB\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1])
